# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision.io import decode_image
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import v2

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Currently using {device}")
# Out:
# Currently using cuda

# %%
train_dir_path = '/kaggle/input/cats-and-dogs-image-classification/train'
test_dir_path = '/kaggle/input/cats-and-dogs-image-classification/test'
classes = os.listdir(train_dir_path)

batch_size = 16
epoches = 50

# %%
transform = v2.Compose([
    v2.RandomResizedCrop(size=(224, 224), antialias=True),
    v2.RandomHorizontalFlip(p=0.5),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
])

# %%
class_transform = {}
for cls in enumerate(classes):
    class_transform[cls[1]] = cls[0]

class_transform
# Out:
# {'dogs': 0, 'cats': 1}

# %%
def Get_paths_and_classes(dir_path):
    classes = os.listdir(dir_path)
    
    img_paths = []
    img_classes = []
    
    for cls in classes:
        class_img_dir_path = os.path.join(dir_path, cls)
        
        paths = [os.path.join(class_img_dir_path, img_name) for img_name in os.listdir(class_img_dir_path)]
        num_of_paths = len(paths)
        
        img_paths.extend(paths)
        img_classes.extend(num_of_paths*[cls])

    return img_paths, img_classes

# %%
train_img_paths, train_classes = Get_paths_and_classes(train_dir_path)
test_img_paths, test_classes = Get_paths_and_classes(test_dir_path)

# %%
class CustomDataset(Dataset):
    def __init__(self, img_paths, classes, img_transform = None, cls_transform = None):
        self.paths = img_paths
        self.classes = classes
        self.img_transform = img_transform
        self.cls_transform = cls_transform
    def __len__(self): 
        return len(self.classes)
    def __getitem__(self, idx):
        img_path = self.paths[idx]
        img = decode_image(img_path)
        if self.img_transform:
            img = transform(img)
            
        cls = self.classes[idx]
        if self.cls_transform:
            cls = self.cls_transform[cls]
            
        return img, cls

# %%
train_data = CustomDataset(train_img_paths, train_classes, transform, class_transform)
test_data = CustomDataset(test_img_paths, test_classes, transform, class_transform)

# %%
train_dataloader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=batch_size, shuffle=True)

# %%
train_features, train_labels = next(iter(train_dataloader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
# Out:
# Feature batch shape: torch.Size([16, 3, 224, 224])
# Labels batch shape: torch.Size([16])

# %%
for idx in range(0,9):
    plt.subplot(3,3, idx+1)
    plt.imshow(train_features[idx].permute(1, 2, 0))
    plt.title('dog' if train_labels[idx] == 0 else 'cat')
    plt.axis('off')

plt.suptitle('Sample Images')
plt.show()

# %%
class ConvModel(nn.Module):
    def __init__(self, inp_features, num_classes):
        super(ConvModel, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(inp_features, 32, 3),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            
            nn.Conv2d(32, 64, 3),
            nn.BatchNorm2d(64),
            nn.ReLU(),
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.LazyLinear(128),
            nn.BatchNorm1d(128),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.BatchNorm1d(64),
            nn.Dropout(0.2),
            nn.Linear(64, num_classes)
        )
    def forward(self, X):
        features = self.features(X)
        result = self.classifier(features)
        return result

# %%
num_of_channels = train_data[0][0].shape[0]
num_of_classes = len(classes)

# %%
model = ConvModel(num_of_channels, num_of_classes)
model.to(device)
# Out:
# ConvModel(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): LazyLinear(in_features=0, out_features=128, bias=True)
#     (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Dropout(p=0.2, inplace=False)
#     (7): Linear(in_features=64, out_features=2, bias=True)
#   )
# )

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
num_of_batches = len(train_dataloader)
training_loss = []
training_accuracy = []

for epoch in range(epoches):
    batch_loss = 0
    batch_accuracy = 0
    for batch, (X, y) in enumerate(train_dataloader):
        X = X.to(device)
        y = y.to(device)

        logits = model(X)
        loss = loss_fn(logits, y)
        y_pred = torch.argmax(F.softmax(logits,dim = 1),dim = 1)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        batch_loss += loss.item()
        batch_accuracy += np.average(accuracy_score(y.cpu(),y_pred.cpu()))
    print(f"For epoch no. {epoch+1} \n average loss = {batch_loss/num_of_batches} \n average accuracy = {batch_accuracy/num_of_batches} \n\n")

    training_loss.append(batch_loss/num_of_batches)
    training_accuracy.append((batch_accuracy/num_of_batches))
# Out:
# For epoch no. 1
#  average loss = 0.7966924599238805
#  average accuracy = 0.49876373626373627
#
#
# For epoch no. 2
#  average loss = 0.7207839301654271
#  average accuracy = 0.5376373626373626
#
#
# For epoch no. 3
#  average loss = 0.6982097591672625
#  average accuracy = 0.5614010989010989
#
#
# For epoch no. 4
#  average loss = 0.7244702117783682
#  average accuracy = 0.556456043956044
#
#
# For epoch no. 5
#  average loss = 0.6983091405459813
#  average accuracy = 0.5479395604395605
#
#
# For epoch no. 6
#  average loss = 0.6943733862468174
#  average accuracy = 0.5925824175824176
#
#
# For epoch no. 7
#  average loss = 0.6953236835343497
#  average accuracy = 0.5756868131868131
#
#
# For epoch no. 8
#  average loss = 0.6982778378895351
#  average accuracy = 0.5902472527472528
#
#
# For epoch no. 9
#  average loss = 0.6976078884942191
#  average accuracy = 0.576923076923077
#
#
# For epoch no. 10
#  average loss = 0.6829764263970511
#  average accuracy = 0.5945054945054945
#
#
# For epoch no. 11
#  average loss = 0.6854946136474609
#  average accuracy = 0.5622252747252747
#
#
# For epoch no. 12
#  average loss = 0.6817515219960893
#  average accuracy = 0.5872252747252747
#
#
# For epoch no. 13
#  average loss = 0.6725087932177952
#  average accuracy = 0.6090659340659341
#
#
# For epoch no. 14
#  average loss = 0.6642777987888882
#  average accuracy = 0.6122252747252748
#
#
# For epoch no. 15
#  average loss = 0.679655761378152
#  average accuracy = 0.5826923076923077
#
#
# For epoch no. 16
#  average loss = 0.6732351439339774
#  average accuracy = 0.5881868131868131
#
#
# For epoch no. 17
#  average loss = 0.6725076045308794
#  average accuracy = 0.6070054945054945
#
#
# For epoch no. 18
#  average loss = 0.673151992048536
#  average accuracy = 0.5931318681318681
#
#
# For epoch no. 19
#  average loss = 0.6689238148076194
#  average accuracy = 0.6288461538461538
#
#
# For epoch no. 20
#  average loss = 0.674329766205379
#  average accuracy = 0.6038461538461538
#
#
# For epoch no. 21
#  average loss = 0.6683330246380397
#  average accuracy = 0.5973901098901099
#
#
# For epoch no. 22
#  average loss = 0.6571253742490496
#  average accuracy = 0.626510989010989
#
#
# For epoch no. 23
#  average loss = 0.6666914224624634
#  average accuracy = 0.6162087912087912
#
#
# For epoch no. 24
#  average loss = 0.6639455795288086
#  average accuracy = 0.6247252747252747
#
#
# For epoch no. 25
#  average loss = 0.6592101795332772
#  average accuracy = 0.6072802197802198
#
#
# For epoch no. 26
#  average loss = 0.6584145324570793
#  average accuracy = 0.5993131868131869
#
#
# For epoch no. 27
#  average loss = 0.6537808878081185
#  average accuracy = 0.6157967032967033
#
#
# For epoch no. 28
#  average loss = 0.6554052455084665
#  average accuracy = 0.6350274725274726
#
#
# For epoch no. 29
#  average loss = 0.6513880780764989
#  average accuracy = 0.6134615384615385
#
#
# For epoch no. 30
#  average loss = 0.6403576459203447
#  average accuracy = 0.6336538461538462
#
#
# For epoch no. 31
#  average loss = 0.6549034305981227
#  average accuracy = 0.601923076923077
#
#
# For epoch no. 32
#  average loss = 0.6623370919908796
#  average accuracy = 0.6100274725274726
#
#
# For epoch no. 33
#  average loss = 0.6489341173853193
#  average accuracy = 0.6015109890109891
#
#
# For epoch no. 34
#  average loss = 0.664295368535178
#  average accuracy = 0.6070054945054945
#
#
# For epoch no. 35
#  average loss = 0.6524536848068238
#  average accuracy = 0.6100274725274726
#
#
# For epoch no. 36
#  average loss = 0.6585328221321106
#  average accuracy = 0.6131868131868131
#
#
# For epoch no. 37
#  average loss = 0.6495536582810538
#  average accuracy = 0.6304945054945055
#
#
# For epoch no. 38
#  average loss = 0.661022185427802
#  average accuracy = 0.6421703296703297
#
#
# For epoch no. 39
#  average loss = 0.6451981714793614
#  average accuracy = 0.6376373626373627
#
#
# For epoch no. 40
#  average loss = 0.648512658051082
#  average accuracy = 0.6122252747252748
#
#
# For epoch no. 41
#  average loss = 0.6512578189373016
#  average accuracy = 0.592032967032967
#
#
# For epoch no. 42
#  average loss = 0.6596972584724426
#  average accuracy = 0.6292582417582417
#
#
# For epoch no. 43
#  average loss = 0.6367829723017556
#  average accuracy = 0.6126373626373627
#
#
# For epoch no. 44
#  average loss = 0.6538413558687483
#  average accuracy = 0.6197802197802198
#
#
# For epoch no. 45
#  average loss = 0.6453200680868966
#  average accuracy = 0.635989010989011
#
#
# For epoch no. 46
#  average loss = 0.6345466954367501
#  average accuracy = 0.6662087912087913
#
#
# For epoch no. 47
#  average loss = 0.6398685387202672
#  average accuracy = 0.646978021978022
#
#
# For epoch no. 48
#  average loss = 0.6523289373942784
#  average accuracy = 0.6287087912087912
#
#
# For epoch no. 49
#  average loss = 0.6438279271125793
#  average accuracy = 0.6385989010989012
#
#
# For epoch no. 50
#  average loss = 0.6496405856949943
#  average accuracy = 0.6296703296703298

# %%
fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.plot(range(0,epoches),training_loss)
ax1.set_title("Training Loss")
ax2.plot(range(0,epoches),training_accuracy)
ax2.set_title("Training Accuracy")
plt.show()

# %%
batch_loss = 0
batch_accuracy = 0
test_num_batches  = len(test_dataloader)

for batch, (X, y) in enumerate(test_dataloader):
    model.eval()
    X = X.to(device)
    y = y.to(device)
    with torch.no_grad():
        logits = model(X)
        loss = loss_fn(logits, y)
        y_pred = torch.argmax(F.softmax(logits,dim = 1),dim = 1)
        batch_loss += loss.item()
        batch_accuracy += np.average(accuracy_score(y.cpu(),y_pred.cpu()))

print(f"average test loss = {batch_loss/test_num_batches}")
print(f"average test loss = {batch_accuracy/test_num_batches}")
# Out:
# average test loss = 0.6766567760043674
# average test loss = 0.5810185185185186
